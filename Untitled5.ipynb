# %%
# Importing the required libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
train_dataset = pd.read_csv("astro_train.csv")
test_dataset = pd.read_csv("astro_test.csv")

# %%
cleaned_train_dataset = train_dataset.drop(["skyVersion","run","rerun","camCol","id"], axis=1)
cleaned_test_dataset = test_dataset.drop(["skyVersion","run","rerun","camCol","id"], axis=1)


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cleaned_train_dataset['dered_i'] = scaler.fit_transform(cleaned_train_dataset[["dered_i"]])
cleaned_train_dataset['dered_z'] = scaler.fit_transform(cleaned_train_dataset[["dered_z"]])
cleaned_train_dataset['dered_g'] = scaler.fit_transform(cleaned_train_dataset[["dered_g"]])
cleaned_train_dataset['dered_u'] = scaler.fit_transform(cleaned_train_dataset[["dered_u"]])
cleaned_train_dataset['dered_r'] = scaler.fit_transform(cleaned_train_dataset[["dered_r"]])
cleaned_train_dataset['err_i'] = scaler.fit_transform(cleaned_train_dataset[["err_i"]])
cleaned_train_dataset['err_z'] = scaler.fit_transform(cleaned_train_dataset[["err_z"]])
cleaned_train_dataset['err_u'] = scaler.fit_transform(cleaned_train_dataset[["err_u"]])
cleaned_train_dataset['err_g'] = scaler.fit_transform(cleaned_train_dataset[["err_g"]])
cleaned_train_dataset['err_r'] = scaler.fit_transform(cleaned_train_dataset[["err_r"]])
cleaned_train_dataset['extinction_r'] = scaler.fit_transform(cleaned_train_dataset[["extinction_r"]])
cleaned_train_dataset['field'] = scaler.fit_transform(cleaned_train_dataset[["field"]])
cleaned_train_dataset['obj'] = scaler.fit_transform(cleaned_train_dataset[["obj"]])
cleaned_train_dataset['photoz'] = scaler.fit_transform(cleaned_train_dataset[["photoz"]])
cleaned_train_dataset['#ra'] = scaler.fit_transform(cleaned_train_dataset[["#ra"]])
cleaned_train_dataset['dec'] = scaler.fit_transform(cleaned_train_dataset[["dec"]])


cleaned_test_dataset['dered_i'] = scaler.fit_transform(cleaned_test_dataset[["dered_i"]])
cleaned_test_dataset['dered_z'] = scaler.fit_transform(cleaned_test_dataset[["dered_z"]])
cleaned_test_dataset['dered_g'] = scaler.fit_transform(cleaned_test_dataset[["dered_g"]])
cleaned_test_dataset['dered_u'] = scaler.fit_transform(cleaned_test_dataset[["dered_u"]])
cleaned_test_dataset['dered_r'] = scaler.fit_transform(cleaned_test_dataset[["dered_r"]])
cleaned_test_dataset['err_i'] = scaler.fit_transform(cleaned_test_dataset[["err_i"]])
cleaned_test_dataset['err_z'] = scaler.fit_transform(cleaned_test_dataset[["err_z"]])
cleaned_test_dataset['err_u'] = scaler.fit_transform(cleaned_test_dataset[["err_u"]])
cleaned_test_dataset['err_g'] = scaler.fit_transform(cleaned_test_dataset[["err_g"]])
cleaned_test_dataset['err_r'] = scaler.fit_transform(cleaned_test_dataset[["err_r"]])
cleaned_test_dataset['extinction_r'] = scaler.fit_transform(cleaned_test_dataset[["extinction_r"]])
cleaned_test_dataset['field'] = scaler.fit_transform(cleaned_test_dataset[["field"]])
cleaned_test_dataset['obj'] = scaler.fit_transform(cleaned_test_dataset[["obj"]])
cleaned_test_dataset['photoz'] = scaler.fit_transform(cleaned_test_dataset[["photoz"]])
cleaned_test_dataset['#ra'] = scaler.fit_transform(cleaned_test_dataset[["#ra"]])
cleaned_test_dataset['dec'] = scaler.fit_transform(cleaned_test_dataset[["dec"]])


#cleaned_train_dataset = (cleaned_train_dataset - cleaned_train_dataset.mean())/cleaned_train_dataset.std()
#cleaned_test_dataset = (cleaned_test_dataset - cleaned_test_dataset.mean())/cleaned_test_dataset.std()


#cleaned_train_dataset=( cleaned_train_dataset- cleaned_train_dataset.min())/( cleaned_train_dataset.max()- cleaned_train_dataset.min())
#cleaned_test_dataset=( cleaned_test_dataset- cleaned_test_dataset.min())/( cleaned_test_dataset.max()- cleaned_test_dataset.min())

# %%
cleaned_train_dataset.head()
# Out:
#     dered_i   dered_z   dered_u   dered_g   dered_r         err_i     err_z  \
# 0  0.260454  0.330439  0.371572  0.309368  0.314703  6.979832e-07  0.000005
# 1  0.343566  0.434069  0.366572  0.356672  0.388068  2.901728e-06  0.000033
# 2  0.465960  0.539930  0.673165  0.578224  0.581721  3.942429e-05  0.000222
# 3  0.255679  0.331329  0.289409  0.277566  0.301989  6.509282e-07  0.000005
# 4  0.454140  0.621303  0.598664  0.511014  0.520046  8.304040e-05  0.002480
#
#           err_u         err_g         err_r  extinction_r     field       obj  \
# 0  9.163166e-08  7.075340e-07  8.134231e-07      0.929401  0.807317  0.001644
# 1  8.131070e-08  1.404225e-06  2.382463e-06      0.883659  0.807317  0.002877
# 2  2.492745e-06  1.256808e-04  1.473204e-04      0.883698  0.807317  0.003288
# 3  2.626554e-08  4.798219e-07  7.060678e-07      0.939258  0.807317  0.004521
# 4  9.042821e-06  7.461908e-05  8.976558e-05      0.939998  0.807317  0.004932
#
#      photoz       #ra       dec  class
# 0  0.522492  0.843932  0.521654      0
# 1  0.519174  0.843939  0.623150      0
# 2  0.310050  0.843929  0.622223      0
# 3  0.444243  0.843951  0.499215      0
# 4  0.243556  0.843962  0.497938      1

# %%
X = cleaned_train_dataset.drop(["class","err_i","err_u"], axis=1)
y = cleaned_train_dataset["class"]

# %%
X.head()
# Out:
#     dered_i   dered_z   dered_u   dered_g   dered_r     err_z         err_g  \
# 0  0.260454  0.330439  0.371572  0.309368  0.314703  0.000005  7.075340e-07
# 1  0.343566  0.434069  0.366572  0.356672  0.388068  0.000033  1.404225e-06
# 2  0.465960  0.539930  0.673165  0.578224  0.581721  0.000222  1.256808e-04
# 3  0.255679  0.331329  0.289409  0.277566  0.301989  0.000005  4.798219e-07
# 4  0.454140  0.621303  0.598664  0.511014  0.520046  0.002480  7.461908e-05
#
#           err_r  extinction_r     field       obj    photoz       #ra  \
# 0  8.134231e-07      0.929401  0.807317  0.001644  0.522492  0.843932
# 1  2.382463e-06      0.883659  0.807317  0.002877  0.519174  0.843939
# 2  1.473204e-04      0.883698  0.807317  0.003288  0.310050  0.843929
# 3  7.060678e-07      0.939258  0.807317  0.004521  0.444243  0.843951
# 4  8.976558e-05      0.939998  0.807317  0.004932  0.243556  0.843962
#
#         dec
# 0  0.521654
# 1  0.623150
# 2  0.622223
# 3  0.499215
# 4  0.497938

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
regressor = RandomForestClassifier(bootstrap= True, max_depth= 80, max_features= 3, min_samples_leaf= 3, min_samples_split= 10, n_estimators=1000,criterion="entropy")

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=80, max_features=3,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test)
# Printing the R^2 score
regressor.score(X_test, y_test)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_pred, y_test)
print("Mean absolute error:", mae)
# Out:
# Mean absolute error: 0.43033333333333335

# %%
X = cleaned_test_dataset.drop(["err_i","err_u"], axis=1)
y_pred = regressor.predict(X)
y_pred = y_pred.astype(int)
output_dataframe = pd.DataFrame({'Id': cleaned_test_dataset.index, 'class': y_pred})

# %%
output_dataframe.to_csv("submissionsexyaf.csv", index=False)
