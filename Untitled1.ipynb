# %%
# Importing the required libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_dataset = pd.read_csv("astro_train.csv")
test_dataset = pd.read_csv("astro_test.csv")

train_dataset = train_dataset.set_index("id")
test_dataset = test_dataset.set_index("id")
train_dataset.head()
# Out:
#     dered_i  dered_z  dered_u  dered_g  dered_r    err_i    err_z    err_u  \
# id
# 0   15.1459  14.9723  18.6394  16.4080  15.4896  0.00195  0.00406  0.02796
# 1   17.3579  17.3498  18.5273  17.6527  17.4296  0.00757  0.02498  0.02484
# 2   20.6154  19.7785  25.4019  23.4824  22.5504  0.10071  0.16768  0.75381
# 3   15.0188  14.9927  16.7971  15.5712  15.1534  0.00183  0.00411  0.00820
# 4   20.3008  21.6454  23.7314  21.7139  20.9195  0.21194  1.86698  2.73388
#
#       err_g    err_r  ...  skyVersion  run  rerun  camCol  field  obj  \
# id                    ...
# 0   0.00279  0.00197  ...           1  745     40       2    518    5
# 1   0.00536  0.00577  ...           1  745     40       2    518    8
# 2   0.46380  0.35679  ...           1  745     40       2    518    9
# 3   0.00195  0.00171  ...           1  745     40       2    518   12
# 4   0.27544  0.21740  ...           1  745     40       2    518   13
#
#      photoz        #ra      dec  class
# id
# 0   2.64988  236.22077 -0.58795      0
# 1   2.63438  236.22135 -0.46320      0
# 2   1.65738  236.22055 -0.46434      0
# 3   2.28431  236.22224 -0.61553      0
# 4   1.34673  236.22307 -0.61710      1
#
# [5 rows x 21 columns]

# %%
train_dataset.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C479E57240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479EAB320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479EDF470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479F0E5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479F3E710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C479F71860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479FA39B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479FD5B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C479FD5B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A03CDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A071EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A0B0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A0E51D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A118320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A14C470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A49F5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A4D2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A506860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A53B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A56EB00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A5A2C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A5D7DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A60BEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A64D080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C47A67F1D0>]],
#       dtype=object)
